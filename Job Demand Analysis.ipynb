# %% [markdown]
# # Job Demand Analyis
#
# ###  In our project we want to see how in-demand skills are trending for data jobs.

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# reading data
df = pd.read_csv('Data Jobs in India.csv', encoding = 'unicode_escape')

# %%
# printing data
df
# Out:
#             job_title_short  \
# 0             Data Engineer
# 1            Data Scientist
# 2            Data Scientist
# 3              Data Analyst
# 4      Senior Data Engineer
# ...                     ...
# 51083         Data Engineer
# 51084          Data Analyst
# 51085     Software Engineer
# 51086      Business Analyst
# 51087     Software Engineer
#
#                                                job_title  \
# 0                                      Big Data Engineer
# 1                                         Data Scientist
# 2                                         Data Scientist
# 3                  Data Quality and Governance Analyst 1
# 4            Senior Data Engineer(Python)-1563,1637&1633
# ...                                                  ...
# 51083                     India - Collections Analyst II
# 51084  Amul Careers 2023 - Apply Online - Data Analys...
# 51085                        Application Support Analyst
# ...

# %%
df.head(10)
# Out:
#         job_title_short                                          job_title  \
# 0         Data Engineer                                  Big Data Engineer
# 1        Data Scientist                                     Data Scientist
# 2        Data Scientist                                     Data Scientist
# 3          Data Analyst              Data Quality and Governance Analyst 1
# 4  Senior Data Engineer        Senior Data Engineer(Python)-1563,1637&1633
# 5         Data Engineer  Director - Enterprise Architecture and Data En...
# 6         Data Engineer                                      Data Engineer
# 7          Data Analyst  Data Analytics work from home job/internship a...
# 8         Data Engineer                              Data Engineering Lead
# 9          Data Analyst                                       Data Analyst
#
#                   job_location  \
# 0     Pune, Maharashtra, India
# 1     Pune, Maharashtra, India
# 2     Pune, Maharashtra, India
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51088 entries, 0 to 51087
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        51088 non-null  object
#  1   job_title              51088 non-null  object
#  2   job_location           51086 non-null  object
#  3   job_via                51088 non-null  object
#  4   job_schedule_type      50993 non-null  object
#  5   job_work_from_home     51088 non-null  bool
#  6   search_location        51088 non-null  object
#  7   job_posted_date        51088 non-null  object
#  8   job_no_degree_mention  51088 non-null  bool
#  9   job_health_insurance   51088 non-null  bool
#  10  job_country            51088 non-null  object
#  11  salary_rate            589 non-null    object
#  12  salary_year_avg        582 non-null    float64
#  13  salary_hour_avg        7 non-null      float64
# ...

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count       582.000000              7.0
# mean     113602.182131             25.0
# std       44919.262828              0.0
# min       32400.000000             25.0
# 25%       79200.000000             25.0
# 50%      111175.000000             25.0
# 75%      147500.000000             25.0
# max      650000.000000             25.0

# %%
# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# extract the month name from 'job_posted_date'
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%B')

# %%
df_pivot = df.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')

# %%
df_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                          170              32           418
# August                         189              25           618
# December                       186              27           648
# February                       143              35           433
# January                        175              31           628
# July                           142              25           457
# June                           146              26           367
# March                          116              37           422
# May                            103              14           278
# November                       192              29           722
# October                        170              36           500
# September                      155              34           630
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
# sort job_posted_month_name in df_pivot by job_posted_month value
df_pivot = df_pivot.reset_index()
df_pivot['job_posted_month_no'] = pd.to_datetime(df_pivot['job_posted_month'], format='%B').dt.month
df_pivot = df_pivot.sort_values('job_posted_month_no')
df_pivot = df_pivot.set_index('job_posted_month')
df_pivot = df_pivot.drop(columns='job_posted_month_no')

df_pivot
# Out:
# job_title_short   index  Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January               4               175              31           628
# February              3               143              35           433
# March                 7               116              37           422
# April                 0               170              32           418
# May                   8               103              14           278
# June                  6               146              26           367
# July                  5               142              25           457
# August                1               189              25           618
# September            11               155              34           630
# October              10               170              36           500
# November              9               192              29           722
# December              2               186              27           648
#
# ...

# %%
df_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
top_3 = df['job_title_short'].value_counts().head(3)
top_3 = top_3.index.tolist()
top_3
# Out:
# ['Data Engineer', 'Data Scientist', 'Data Analyst']

# %%
df_pivot[top_3].plot(kind='line')
plt.title('Monthly Job Postings for Top Data Jobs in the US')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.legend()
plt.show()
